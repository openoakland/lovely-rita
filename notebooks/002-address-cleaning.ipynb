# %% [markdown]
# A demonstration of the address cleaning process.

# %%
# %matplotlib inline

# %%
import re
import matplotlib.pyplot as plt
import pandas as pd
from lovelyrita.data import read_data, column_map, summarize
from lovelyrita.clean import get_datetime, clean, impute_missing_times, drop_void
from lovelyrita.addresses import REPLACEMENTS

plt.style.use('seaborn')

# %% [markdown]
# # Load citations

# %%
data_paths = [
              "/data/lovely-rita/new/2012complete-output.csv",
              "/data/lovely-rita/new/2013complete-output.csv",
              "/data/lovely-rita/new/2014complete-output.csv",
              "/data/lovely-rita/new/2015complete-output.csv",
              "/data/lovely-rita/new/2016complete-output-2.csv"
             ]

# %%
citations = read_data(data_paths, clean=False)

# %%
citations['street_name'] = None
citations['street_no'] = None
citations.drop(['street_suffix'], axis=1, inplace=True)

# %%
summarize(citations)
# Out:
#                 Column Name Data Type  Unique Count          Sample Value  \
# 1                      city    object             2               oakland
# 3                     state    object             2            california
# 4                    street    object        174339  6100 OLD QUARRY LOOP
# 0              badge_number    object          1462                   937
# 7         ticket_issue_date    object          1828                1/1/12
# 9             ticket_number    object       1645813             838880801
# 10      violation_desc_long    object            88    OBEDIENCE TO SIGNS
# 11  violation_external_code    object            99             10.16.110
# 8         ticket_issue_time    object          2872              10:30:00
# 2               fine_amount    object            68                   $73
# 5               street_name    object             1                  None
# 6                 street_no    object             1                  None
#
#        null  % null
# 1         0    0.00
# 3         0    0.00
# 4         0    0.00
# 0         1    0.00
# 7         1    0.00
# 9         1    0.00
# 10        1    0.00
# 11        1    0.00
# 8       120    0.01
# 2       409    0.02
# 5   1645813  100.00
# 6   1645813  100.00

# %% [markdown]
# # Parsing the street name

# %% [markdown]
# # What is the address format in the raw data?
# Are addresses parsed into name and number? Or are they all inferred from `street`?
#
# In any case, we can check database versions of those values with those parsed from the `street` field.

# %% [markdown]
# # Text replacements
# Some things are easier to just replace at the outset. Use this strategy sparingly, since each replacement takes a lot of time.

# %%
for pattern, replacement in REPLACEMENTS:
    citations['street'].replace(pattern, replacement, regex=True, inplace=True)

# %% [markdown]
# ## Lots
# Many citations are in parking lots. Those will not have street numbers, so we should treat them separately. We will only concern ourselves with potential street addresses.

# %%
lot_indices = citations.street.str.contains('^[A-Z]LOT.*LOT$')
street_citations = citations.loc[~lot_indices]

# %% [markdown]
# ## The most common pattern, 123 MAIN STREET

# %%
patt = re.compile(r'^(?P<street_no>\d+\-?\d?) (?P<street_name>[\w\d\s]+)')

# %%
street = street_citations.street.str.extract(patt, expand=True)
street.dropna(inplace=True)

# %%
citations.update(street)

# %%
summarize(citations)
# Out:
#                 Column Name Data Type  Unique Count          Sample Value  \
# 1                      city    object             2               oakland
# 3                     state    object             2            california
# 4                    street    object        174324  6100 OLD QUARRY LOOP
# 0              badge_number    object          1462                   937
# 7         ticket_issue_date    object          1828                1/1/12
# 9             ticket_number    object       1645813             838880801
# 10      violation_desc_long    object            88    OBEDIENCE TO SIGNS
# 11  violation_external_code    object            99             10.16.110
# 8         ticket_issue_time    object          2872              10:30:00
# 2               fine_amount    object            68                   $73
# 5               street_name    object          4476       OLD QUARRY LOOP
# 6                 street_no    object         11303                  6100
#
#      null  % null
# 1       0    0.00
# 3       0    0.00
# 4       0    0.00
# 0       1    0.00
# 7       1    0.00
# 9       1    0.00
# 10      1    0.00
# 11      1    0.00
# 8     120    0.01
# 2     409    0.02
# 5   27485    1.67
# 6   27485    1.67

# %% [markdown]
# That covers over 98% of all citations.

# %%
citations.head()
# Out:
#   badge_number     city fine_amount       state                street  \
# 0          937  oakland         $73  california  6100 OLD QUARRY LOOP
# 1         8961  oakland        $263  california         1800 12TH AVE
# 2         1855  oakland         $73  california      300 OAK COLISEUM
# 3         1071  oakland         $73  california       1 AIRPORT DRIVE
# 4        R1186  oakland         $73  california       1 AIRPORT DRIVE
#
#        street_name street_no ticket_issue_date ticket_issue_time  \
# 0  OLD QUARRY LOOP      6100            1/1/12          10:30:00
# 1         12TH AVE      1800            1/1/12          12:00:00
# 2     OAK COLISEUM       300            1/1/12          13:50:00
# 3    AIRPORT DRIVE         1            1/2/12          10:40:00
# 4    AIRPORT DRIVE         1            1/2/12          16:00:00
#
#   ticket_number   violation_desc_long violation_external_code
# 0     838880801    OBEDIENCE TO SIGNS               10.16.110
# 1     838907806  COMM VEH IN RESIDENT               10.28.120
# 2     839915330          NO VALID REG                   4000A
# 3     834934276    OBEDIENCE TO SIGNS               10.16.110
# 4     839892207    OBEDIENCE TO SIGNS               10.16.110

# %% [markdown]
# ## A less common pattern, P123-1 PARK STREET

# %%
patt = re.compile(r'^(?P<prefix>[A-Z]+)\-?(?P<street_no>\d+[\-\W]?\d?) '
                   '(?P<street_name>[\w\d\s]+)')
street = street_citations.street.str.extract(patt, expand=True)

# %%
street.dropna(inplace=True)

# %%
drop_indices = []
for i, s in street.iterrows():
    street_words = s.street_name.split(' ')
    drop = True
    for street_word in street_words:
        if street_word.startswith(s.prefix[0]):
            drop = False
    if drop:
        drop_indices.append(i)

# %%
street.drop(drop_indices, inplace=True)

# %%
citations.update(street)

# %%
lot_indices = citations.street.str.contains('^[A-Z]LOT.*LOT$')
street_citations = citations.loc[~lot_indices]

# %%
summarize(citations)
# Out:
#                 Column Name Data Type  Unique Count          Sample Value  \
# 1                      city    object             2               oakland
# 3                     state    object             2            california
# 4                    street    object        174324  6100 OLD QUARRY LOOP
# 0              badge_number    object          1462                   937
# 7         ticket_issue_date    object          1828                1/1/12
# 9             ticket_number    object       1645813             838880801
# 10      violation_desc_long    object            88    OBEDIENCE TO SIGNS
# 11  violation_external_code    object            99             10.16.110
# 8         ticket_issue_time    object          2872              10:30:00
# 2               fine_amount    object            68                   $73
# 5               street_name    object          4486       OLD QUARRY LOOP
# 6                 street_no    object         11542                  6100
#
#      null  % null
# 1       0    0.00
# 3       0    0.00
# 4       0    0.00
# 0       1    0.00
# 7       1    0.00
# 9       1    0.00
# 10      1    0.00
# 11      1    0.00
# 8     120    0.01
# 2     409    0.02
# 5   13388    0.81
# 6   13388    0.81

# %% [markdown]
# # 99.2% successfully parsed
# The rest are a mix of things that we should have parsed and things that actually contain no street number (parking lots, cross streets, etc.).

# %% [markdown]
# # All-in-one function

# %%
from lovelyrita.addresses import parse_addresses

# %%
street = parse_addresses(citations.street)

# %%
citations.update(street)

# %%
citations.head()
# Out:
#   badge_number     city fine_amount       state                street  \
# 0          937  oakland         $73  california  6100 OLD QUARRY LOOP
# 1         8961  oakland        $263  california         1800 12TH AVE
# 2         1855  oakland         $73  california      300 OAK COLISEUM
# 3         1071  oakland         $73  california       1 AIRPORT DRIVE
# 4        R1186  oakland         $73  california       1 AIRPORT DRIVE
#
#        street_name street_no ticket_issue_date ticket_issue_time  \
# 0  OLD QUARRY LOOP      6100            1/1/12          10:30:00
# 1         12TH AVE      1800            1/1/12          12:00:00
# 2     OAK COLISEUM       300            1/1/12          13:50:00
# 3    AIRPORT DRIVE         1            1/2/12          10:40:00
# 4    AIRPORT DRIVE         1            1/2/12          16:00:00
#
#   ticket_number   violation_desc_long violation_external_code
# 0     838880801    OBEDIENCE TO SIGNS               10.16.110
# 1     838907806  COMM VEH IN RESIDENT               10.28.120
# 2     839915330          NO VALID REG                   4000A
# 3     834934276    OBEDIENCE TO SIGNS               10.16.110
# 4     839892207    OBEDIENCE TO SIGNS               10.16.110
